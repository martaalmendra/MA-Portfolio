# %%
import pandas as pd
import numpy as np
import time
import re
import string
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer


#Classification and Metrics
from sklearn.model_selection import GridSearchCV, train_test_split, PredefinedSplit
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.multioutput import ClassifierChain
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.multiclass import OneVsRestClassifier
from sklearn.metrics import classification_report, f1_score

from sklearn import metrics

# %load_ext autoreload
# %autoreload 2
import warnings
warnings.filterwarnings('ignore')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
clean_reviews = pd.read_csv('/content/drive/MyDrive/modelling/clean_reviews_dataset.csv')

# %%
clean_reviews = clean_reviews.dropna(subset=['cleaned_reviews_reduced_words'])
clean_reviews = clean_reviews[clean_reviews['cleaned_reviews_reduced_words'].apply(lambda x: len(str(x)) > 0)]

# %%
mlb = MultiLabelBinarizer()
binarised_labels = mlb.fit_transform(clean_reviews['Cuisines'])
clean_reviews['labels'] = binarised_labels.tolist()

# %%
X_train, X_test, y_train, y_test = train_test_split(
    clean_reviews['cleaned_reviews_reduced_words'], binarised_labels, test_size=0.2, random_state=42, stratify=binarised_labels)

X_train = np.array([str(x) for x in X_train])

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42 )

# %%
X_train_full = np.concatenate((X_train, X_val), axis = 0)
y_train_full = np.concatenate((y_train, y_val), axis = 0)

split_index = [-1]* len(X_train) + [0] * len(X_val)
predefined_split = PredefinedSplit(test_fold = split_index)

# %%
bigram_tfidf_vectorizer = TfidfVectorizer(ngram_range=(1,1), token_pattern=r"(?u)\b\w+\b")
bigram_bow_vectorizer = CountVectorizer(ngram_range=(1,1), token_pattern=r"(?u)\b\w+\b")

# %%
scores = ["accuracy", "precision_weighted", "recall_weighted", "f1_weighted"]

# %% [markdown]
# #### One Vs Rest

# %%
from sklearn.tree import DecisionTreeClassifier

pipeline_dt = Pipeline([
    ('vectorizer', bigram_tfidf_vectorizer),
    ('classifier', OneVsRestClassifier(DecisionTreeClassifier(random_state=42)))])

param_grid_dt = {
    'vectorizer': [bigram_tfidf_vectorizer, bigram_bow_vectorizer],
    'classifier__estimator__max_depth': [None, 10, 20, 30],
    'classifier__estimator__min_samples_split': [2, 5, 10],
    'classifier__estimator__min_samples_leaf': [1, 2, 4]}

grid_search_dt = GridSearchCV(
    estimator=pipeline_dt,
    param_grid=param_grid_dt,
    scoring=scores,
    cv = predefined_split,
    refit="f1_weighted",
    verbose=4)

grid_result_dt = grid_search_dt.fit(X_train_full, y_train_full)
# Out:
# Fitting 1 folds for each of 72 candidates, totalling 72 fits
# [CV 1/1] END classifier__estimator__max_depth=None, classifier__estimator__min_samples_leaf=1, classifier__estimator__min_samples_split=2, vectorizer=TfidfVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.048) f1_weighted: (test=0.840) precision_weighted: (test=0.841) recall_weighted: (test=0.840) total time= 2.7min
# [CV 1/1] END classifier__estimator__max_depth=None, classifier__estimator__min_samples_leaf=1, classifier__estimator__min_samples_split=2, vectorizer=CountVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.045) f1_weighted: (test=0.830) precision_weighted: (test=0.837) recall_weighted: (test=0.824) total time= 1.0min
# [CV 1/1] END classifier__estimator__max_depth=None, classifier__estimator__min_samples_leaf=1, classifier__estimator__min_samples_split=5, vectorizer=TfidfVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.048) f1_weighted: (test=0.839) precision_weighted: (test=0.841) recall_weighted: (test=0.838) total time= 2.6min
# [CV 1/1] END classifier__estimator__max_depth=None, classifier__estimator__min_samples_leaf=1, classifier__estimator__min_samples_split=5, vectorizer=CountVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.051) f1_weighted: (test=0.839) precision_weighted: (test=0.846) recall_weighted: (test=0.836) total time=  58.3s
# [CV 1/1] END classifier__estimator__max_depth=None, classifier__estimator__min_samples_leaf=1, classifier__estimator__min_samples_split=10, vectorizer=TfidfVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.049) f1_weighted: (test=0.838) precision_weighted: (test=0.841) recall_weighted: (test=0.836) total time= 2.6min
# [CV 1/1] END classifier__estimator__max_depth=None, classifier__estimator__min_samples_leaf=1, classifier__estimator__min_samples_split=10, vectorizer=CountVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.060) f1_weighted: (test=0.842) precision_weighted: (test=0.848) recall_weighted: (test=0.840) total time=  52.9s
# [CV 1/1] END classifier__estimator__max_depth=None, classifier__estimator__min_samples_leaf=2, classifier__estimator__min_samples_split=2, vectorizer=TfidfVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.037) f1_weighted: (test=0.826) precision_weighted: (test=0.845) recall_weighted: (test=0.811) total time= 2.1min
# [CV 1/1] END classifier__estimator__max_depth=None, classifier__estimator__min_samples_leaf=2, classifier__estimator__min_samples_split=2, vectorizer=CountVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.053) f1_weighted: (test=0.828) precision_weighted: (test=0.849) recall_weighted: (test=0.812) total time=  43.9s
# [CV 1/1] END classifier__estimator__max_depth=None, classifier__estimator__min_samples_leaf=2, classifier__estimator__min_samples_split=5, vectorizer=TfidfVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.038) f1_weighted: (test=0.826) precision_weighted: (test=0.846) recall_weighted: (test=0.811) total time= 2.2min
# [CV 1/1] END classifier__estimator__max_depth=None, classifier__estimator__min_samples_leaf=2, classifier__estimator__min_samples_split=5, vectorizer=CountVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.047) f1_weighted: (test=0.831) precision_weighted: (test=0.852) recall_weighted: (test=0.816) total time=  42.1s
# [CV 1/1] END classifier__estimator__max_depth=None, classifier__estimator__min_samples_leaf=2, classifier__estimator__min_samples_split=10, vectorizer=TfidfVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.046) f1_weighted: (test=0.829) precision_weighted: (test=0.847) recall_weighted: (test=0.816) total time= 2.1min
# [CV 1/1] END classifier__estimator__max_depth=None, classifier__estimator__min_samples_leaf=2, classifier__estimator__min_samples_split=10, vectorizer=CountVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.059) f1_weighted: (test=0.833) precision_weighted: (test=0.855) recall_weighted: (test=0.820) total time=  39.8s
# [CV 1/1] END classifier__estimator__max_depth=None, classifier__estimator__min_samples_leaf=4, classifier__estimator__min_samples_split=2, vectorizer=TfidfVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.042) f1_weighted: (test=0.828) precision_weighted: (test=0.847) recall_weighted: (test=0.815) total time= 1.6min
# [CV 1/1] END classifier__estimator__max_depth=None, classifier__estimator__min_samples_leaf=4, classifier__estimator__min_samples_split=2, vectorizer=CountVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.055) f1_weighted: (test=0.835) precision_weighted: (test=0.852) recall_weighted: (test=0.828) total time=  32.1s
# [CV 1/1] END classifier__estimator__max_depth=None, classifier__estimator__min_samples_leaf=4, classifier__estimator__min_samples_split=5, vectorizer=TfidfVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.042) f1_weighted: (test=0.828) precision_weighted: (test=0.847) recall_weighted: (test=0.815) total time= 1.6min
# [CV 1/1] END classifier__estimator__max_depth=None, classifier__estimator__min_samples_leaf=4, classifier__estimator__min_samples_split=5, vectorizer=CountVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.055) f1_weighted: (test=0.835) precision_weighted: (test=0.852) recall_weighted: (test=0.828) total time=  33.4s
# [CV 1/1] END classifier__estimator__max_depth=None, classifier__estimator__min_samples_leaf=4, classifier__estimator__min_samples_split=10, vectorizer=TfidfVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.050) f1_weighted: (test=0.830) precision_weighted: (test=0.846) recall_weighted: (test=0.819) total time= 1.5min
# [CV 1/1] END classifier__estimator__max_depth=None, classifier__estimator__min_samples_leaf=4, classifier__estimator__min_samples_split=10, vectorizer=CountVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.054) f1_weighted: (test=0.835) precision_weighted: (test=0.852) recall_weighted: (test=0.828) total time=  32.5s
# [CV 1/1] END classifier__estimator__max_depth=10, classifier__estimator__min_samples_leaf=1, classifier__estimator__min_samples_split=2, vectorizer=TfidfVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.094) f1_weighted: (test=0.832) precision_weighted: (test=0.861) recall_weighted: (test=0.860) total time=  10.9s
# [CV 1/1] END classifier__estimator__max_depth=10, classifier__estimator__min_samples_leaf=1, classifier__estimator__min_samples_split=2, vectorizer=CountVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.096) f1_weighted: (test=0.832) precision_weighted: (test=0.863) recall_weighted: (test=0.857) total time=   5.0s
# [CV 1/1] END classifier__estimator__max_depth=10, classifier__estimator__min_samples_leaf=1, classifier__estimator__min_samples_split=5, vectorizer=TfidfVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.095) f1_weighted: (test=0.832) precision_weighted: (test=0.861) recall_weighted: (test=0.860) total time=  11.0s
# [CV 1/1] END classifier__estimator__max_depth=10, classifier__estimator__min_samples_leaf=1, classifier__estimator__min_samples_split=5, vectorizer=CountVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.095) f1_weighted: (test=0.832) precision_weighted: (test=0.863) recall_weighted: (test=0.857) total time=   4.6s
# [CV 1/1] END classifier__estimator__max_depth=10, classifier__estimator__min_samples_leaf=1, classifier__estimator__min_samples_split=10, vectorizer=TfidfVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.095) f1_weighted: (test=0.832) precision_weighted: (test=0.861) recall_weighted: (test=0.860) total time=  11.0s
# [CV 1/1] END classifier__estimator__max_depth=10, classifier__estimator__min_samples_leaf=1, classifier__estimator__min_samples_split=10, vectorizer=CountVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.096) f1_weighted: (test=0.831) precision_weighted: (test=0.863) recall_weighted: (test=0.856) total time=   4.2s
# [CV 1/1] END classifier__estimator__max_depth=10, classifier__estimator__min_samples_leaf=2, classifier__estimator__min_samples_split=2, vectorizer=TfidfVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.095) f1_weighted: (test=0.831) precision_weighted: (test=0.861) recall_weighted: (test=0.858) total time=  10.8s
# [CV 1/1] END classifier__estimator__max_depth=10, classifier__estimator__min_samples_leaf=2, classifier__estimator__min_samples_split=2, vectorizer=CountVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.096) f1_weighted: (test=0.831) precision_weighted: (test=0.863) recall_weighted: (test=0.855) total time=   4.1s
# [CV 1/1] END classifier__estimator__max_depth=10, classifier__estimator__min_samples_leaf=2, classifier__estimator__min_samples_split=5, vectorizer=TfidfVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.095) f1_weighted: (test=0.831) precision_weighted: (test=0.862) recall_weighted: (test=0.859) total time=  10.9s
# [CV 1/1] END classifier__estimator__max_depth=10, classifier__estimator__min_samples_leaf=2, classifier__estimator__min_samples_split=5, vectorizer=CountVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.096) f1_weighted: (test=0.830) precision_weighted: (test=0.862) recall_weighted: (test=0.855) total time=   4.5s
# [CV 1/1] END classifier__estimator__max_depth=10, classifier__estimator__min_samples_leaf=2, classifier__estimator__min_samples_split=10, vectorizer=TfidfVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.092) f1_weighted: (test=0.831) precision_weighted: (test=0.861) recall_weighted: (test=0.859) total time=  11.1s
# [CV 1/1] END classifier__estimator__max_depth=10, classifier__estimator__min_samples_leaf=2, classifier__estimator__min_samples_split=10, vectorizer=CountVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.096) f1_weighted: (test=0.831) precision_weighted: (test=0.863) recall_weighted: (test=0.855) total time=   4.2s
# [CV 1/1] END classifier__estimator__max_depth=10, classifier__estimator__min_samples_leaf=4, classifier__estimator__min_samples_split=2, vectorizer=TfidfVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.095) f1_weighted: (test=0.829) precision_weighted: (test=0.860) recall_weighted: (test=0.856) total time=  10.6s
# [CV 1/1] END classifier__estimator__max_depth=10, classifier__estimator__min_samples_leaf=4, classifier__estimator__min_samples_split=2, vectorizer=CountVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.096) f1_weighted: (test=0.829) precision_weighted: (test=0.860) recall_weighted: (test=0.854) total time=   3.9s
# [CV 1/1] END classifier__estimator__max_depth=10, classifier__estimator__min_samples_leaf=4, classifier__estimator__min_samples_split=5, vectorizer=TfidfVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.095) f1_weighted: (test=0.829) precision_weighted: (test=0.860) recall_weighted: (test=0.856) total time=  10.5s
# [CV 1/1] END classifier__estimator__max_depth=10, classifier__estimator__min_samples_leaf=4, classifier__estimator__min_samples_split=5, vectorizer=CountVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.096) f1_weighted: (test=0.829) precision_weighted: (test=0.860) recall_weighted: (test=0.854) total time=   4.0s
# [CV 1/1] END classifier__estimator__max_depth=10, classifier__estimator__min_samples_leaf=4, classifier__estimator__min_samples_split=10, vectorizer=TfidfVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.096) f1_weighted: (test=0.829) precision_weighted: (test=0.860) recall_weighted: (test=0.857) total time=  10.6s
# [CV 1/1] END classifier__estimator__max_depth=10, classifier__estimator__min_samples_leaf=4, classifier__estimator__min_samples_split=10, vectorizer=CountVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.097) f1_weighted: (test=0.829) precision_weighted: (test=0.861) recall_weighted: (test=0.854) total time=   3.9s
# [CV 1/1] END classifier__estimator__max_depth=20, classifier__estimator__min_samples_leaf=1, classifier__estimator__min_samples_split=2, vectorizer=TfidfVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.100) f1_weighted: (test=0.845) precision_weighted: (test=0.864) recall_weighted: (test=0.864) total time=  20.0s
# [CV 1/1] END classifier__estimator__max_depth=20, classifier__estimator__min_samples_leaf=1, classifier__estimator__min_samples_split=2, vectorizer=CountVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.113) f1_weighted: (test=0.846) precision_weighted: (test=0.863) recall_weighted: (test=0.864) total time=   9.7s
# [CV 1/1] END classifier__estimator__max_depth=20, classifier__estimator__min_samples_leaf=1, classifier__estimator__min_samples_split=5, vectorizer=TfidfVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.100) f1_weighted: (test=0.845) precision_weighted: (test=0.864) recall_weighted: (test=0.864) total time=  19.7s
# [CV 1/1] END classifier__estimator__max_depth=20, classifier__estimator__min_samples_leaf=1, classifier__estimator__min_samples_split=5, vectorizer=CountVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.111) f1_weighted: (test=0.845) precision_weighted: (test=0.863) recall_weighted: (test=0.863) total time=   9.8s
# [CV 1/1] END classifier__estimator__max_depth=20, classifier__estimator__min_samples_leaf=1, classifier__estimator__min_samples_split=10, vectorizer=TfidfVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.100) f1_weighted: (test=0.845) precision_weighted: (test=0.864) recall_weighted: (test=0.864) total time=  20.9s
# [CV 1/1] END classifier__estimator__max_depth=20, classifier__estimator__min_samples_leaf=1, classifier__estimator__min_samples_split=10, vectorizer=CountVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.113) f1_weighted: (test=0.846) precision_weighted: (test=0.865) recall_weighted: (test=0.863) total time=   9.5s
# [CV 1/1] END classifier__estimator__max_depth=20, classifier__estimator__min_samples_leaf=2, classifier__estimator__min_samples_split=2, vectorizer=TfidfVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.098) f1_weighted: (test=0.844) precision_weighted: (test=0.865) recall_weighted: (test=0.862) total time=  19.1s
# [CV 1/1] END classifier__estimator__max_depth=20, classifier__estimator__min_samples_leaf=2, classifier__estimator__min_samples_split=2, vectorizer=CountVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.110) f1_weighted: (test=0.843) precision_weighted: (test=0.864) recall_weighted: (test=0.860) total time=   9.5s
# [CV 1/1] END classifier__estimator__max_depth=20, classifier__estimator__min_samples_leaf=2, classifier__estimator__min_samples_split=5, vectorizer=TfidfVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.102) f1_weighted: (test=0.844) precision_weighted: (test=0.864) recall_weighted: (test=0.862) total time=  20.0s
# [CV 1/1] END classifier__estimator__max_depth=20, classifier__estimator__min_samples_leaf=2, classifier__estimator__min_samples_split=5, vectorizer=CountVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.113) f1_weighted: (test=0.843) precision_weighted: (test=0.864) recall_weighted: (test=0.860) total time=   9.2s
# [CV 1/1] END classifier__estimator__max_depth=20, classifier__estimator__min_samples_leaf=2, classifier__estimator__min_samples_split=10, vectorizer=TfidfVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.103) f1_weighted: (test=0.845) precision_weighted: (test=0.865) recall_weighted: (test=0.863) total time=  19.2s
# [CV 1/1] END classifier__estimator__max_depth=20, classifier__estimator__min_samples_leaf=2, classifier__estimator__min_samples_split=10, vectorizer=CountVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.117) f1_weighted: (test=0.844) precision_weighted: (test=0.867) recall_weighted: (test=0.861) total time=   8.9s
# [CV 1/1] END classifier__estimator__max_depth=20, classifier__estimator__min_samples_leaf=4, classifier__estimator__min_samples_split=2, vectorizer=TfidfVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.103) f1_weighted: (test=0.841) precision_weighted: (test=0.864) recall_weighted: (test=0.859) total time=  18.6s
# [CV 1/1] END classifier__estimator__max_depth=20, classifier__estimator__min_samples_leaf=4, classifier__estimator__min_samples_split=2, vectorizer=CountVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.105) f1_weighted: (test=0.842) precision_weighted: (test=0.863) recall_weighted: (test=0.858) total time=   7.8s
# [CV 1/1] END classifier__estimator__max_depth=20, classifier__estimator__min_samples_leaf=4, classifier__estimator__min_samples_split=5, vectorizer=TfidfVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.103) f1_weighted: (test=0.841) precision_weighted: (test=0.864) recall_weighted: (test=0.859) total time=  19.2s
# [CV 1/1] END classifier__estimator__max_depth=20, classifier__estimator__min_samples_leaf=4, classifier__estimator__min_samples_split=5, vectorizer=CountVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.105) f1_weighted: (test=0.842) precision_weighted: (test=0.863) recall_weighted: (test=0.858) total time=   7.2s
# [CV 1/1] END classifier__estimator__max_depth=20, classifier__estimator__min_samples_leaf=4, classifier__estimator__min_samples_split=10, vectorizer=TfidfVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.104) f1_weighted: (test=0.842) precision_weighted: (test=0.864) recall_weighted: (test=0.860) total time=  19.8s
# [CV 1/1] END classifier__estimator__max_depth=20, classifier__estimator__min_samples_leaf=4, classifier__estimator__min_samples_split=10, vectorizer=CountVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.107) f1_weighted: (test=0.842) precision_weighted: (test=0.863) recall_weighted: (test=0.858) total time=   8.6s
# [CV 1/1] END classifier__estimator__max_depth=30, classifier__estimator__min_samples_leaf=1, classifier__estimator__min_samples_split=2, vectorizer=TfidfVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.103) f1_weighted: (test=0.851) precision_weighted: (test=0.861) recall_weighted: (test=0.867) total time=  29.0s
# [CV 1/1] END classifier__estimator__max_depth=30, classifier__estimator__min_samples_leaf=1, classifier__estimator__min_samples_split=2, vectorizer=CountVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.106) f1_weighted: (test=0.849) precision_weighted: (test=0.863) recall_weighted: (test=0.864) total time=  12.9s
# [CV 1/1] END classifier__estimator__max_depth=30, classifier__estimator__min_samples_leaf=1, classifier__estimator__min_samples_split=5, vectorizer=TfidfVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.107) f1_weighted: (test=0.851) precision_weighted: (test=0.861) recall_weighted: (test=0.867) total time=  29.5s
# [CV 1/1] END classifier__estimator__max_depth=30, classifier__estimator__min_samples_leaf=1, classifier__estimator__min_samples_split=5, vectorizer=CountVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.105) f1_weighted: (test=0.849) precision_weighted: (test=0.863) recall_weighted: (test=0.863) total time=  12.7s
# [CV 1/1] END classifier__estimator__max_depth=30, classifier__estimator__min_samples_leaf=1, classifier__estimator__min_samples_split=10, vectorizer=TfidfVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.102) f1_weighted: (test=0.851) precision_weighted: (test=0.861) recall_weighted: (test=0.867) total time=  28.9s
# [CV 1/1] END classifier__estimator__max_depth=30, classifier__estimator__min_samples_leaf=1, classifier__estimator__min_samples_split=10, vectorizer=CountVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.105) f1_weighted: (test=0.849) precision_weighted: (test=0.864) recall_weighted: (test=0.863) total time=  11.5s
# [CV 1/1] END classifier__estimator__max_depth=30, classifier__estimator__min_samples_leaf=2, classifier__estimator__min_samples_split=2, vectorizer=TfidfVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.094) f1_weighted: (test=0.849) precision_weighted: (test=0.863) recall_weighted: (test=0.864) total time=  27.8s
# [CV 1/1] END classifier__estimator__max_depth=30, classifier__estimator__min_samples_leaf=2, classifier__estimator__min_samples_split=2, vectorizer=CountVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.105) f1_weighted: (test=0.847) precision_weighted: (test=0.864) recall_weighted: (test=0.859) total time=  12.5s
# [CV 1/1] END classifier__estimator__max_depth=30, classifier__estimator__min_samples_leaf=2, classifier__estimator__min_samples_split=5, vectorizer=TfidfVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.098) f1_weighted: (test=0.849) precision_weighted: (test=0.863) recall_weighted: (test=0.864) total time=  28.8s
# [CV 1/1] END classifier__estimator__max_depth=30, classifier__estimator__min_samples_leaf=2, classifier__estimator__min_samples_split=5, vectorizer=CountVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.099) f1_weighted: (test=0.847) precision_weighted: (test=0.863) recall_weighted: (test=0.859) total time=  11.9s
# [CV 1/1] END classifier__estimator__max_depth=30, classifier__estimator__min_samples_leaf=2, classifier__estimator__min_samples_split=10, vectorizer=TfidfVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.097) f1_weighted: (test=0.849) precision_weighted: (test=0.862) recall_weighted: (test=0.864) total time=  28.2s
# [CV 1/1] END classifier__estimator__max_depth=30, classifier__estimator__min_samples_leaf=2, classifier__estimator__min_samples_split=10, vectorizer=CountVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.105) f1_weighted: (test=0.848) precision_weighted: (test=0.866) recall_weighted: (test=0.860) total time=  10.9s
# [CV 1/1] END classifier__estimator__max_depth=30, classifier__estimator__min_samples_leaf=4, classifier__estimator__min_samples_split=2, vectorizer=TfidfVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.096) f1_weighted: (test=0.847) precision_weighted: (test=0.861) recall_weighted: (test=0.860) total time=  26.4s
# [CV 1/1] END classifier__estimator__max_depth=30, classifier__estimator__min_samples_leaf=4, classifier__estimator__min_samples_split=2, vectorizer=CountVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.100) f1_weighted: (test=0.846) precision_weighted: (test=0.862) recall_weighted: (test=0.857) total time=  12.7s
# [CV 1/1] END classifier__estimator__max_depth=30, classifier__estimator__min_samples_leaf=4, classifier__estimator__min_samples_split=5, vectorizer=TfidfVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.096) f1_weighted: (test=0.847) precision_weighted: (test=0.861) recall_weighted: (test=0.860) total time=  27.8s
# [CV 1/1] END classifier__estimator__max_depth=30, classifier__estimator__min_samples_leaf=4, classifier__estimator__min_samples_split=5, vectorizer=CountVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.100) f1_weighted: (test=0.846) precision_weighted: (test=0.862) recall_weighted: (test=0.857) total time=  11.8s
# [CV 1/1] END classifier__estimator__max_depth=30, classifier__estimator__min_samples_leaf=4, classifier__estimator__min_samples_split=10, vectorizer=TfidfVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.100) f1_weighted: (test=0.847) precision_weighted: (test=0.861) recall_weighted: (test=0.861) total time=  25.3s
# [CV 1/1] END classifier__estimator__max_depth=30, classifier__estimator__min_samples_leaf=4, classifier__estimator__min_samples_split=10, vectorizer=CountVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.101) f1_weighted: (test=0.846) precision_weighted: (test=0.861) recall_weighted: (test=0.857) total time=  11.3s

# %%
print("Best Parameters (Decision Trees One Vs Rest): ", grid_result_dt.best_params_)
# Out:
# Best Parameters (Decision Trees One Vs Rest):  {'classifier__estimator__max_depth': 30, 'classifier__estimator__min_samples_leaf': 1, 'classifier__estimator__min_samples_split': 10, 'vectorizer': TfidfVectorizer(token_pattern='(?u)\\b\\w+\\b')}

# %%
for score in scores:
    mean_score = grid_result_dt.cv_results_[f'mean_test_{score}'][grid_result_dt.best_index_]
    print(f"Decision Tree One Vs Rest: \n{score} = {round(mean_score, 3)}")
# Out:
# Decision Tree One Vs Rest:
# accuracy = 0.102
# Decision Tree One Vs Rest:
# precision_weighted = 0.861
# Decision Tree One Vs Rest:
# recall_weighted = 0.867
# Decision Tree One Vs Rest:
# f1_weighted = 0.851

# %% [markdown]
# Classifier Chain

# %%
pipeline_dt_cchain = Pipeline([
    ('vectorizer', bigram_tfidf_vectorizer),
    ('classifier', ClassifierChain(DecisionTreeClassifier(random_state=42)))])

param_grid_dt_cchain = {
    'vectorizer': [bigram_tfidf_vectorizer],
    'classifier__order' : [None, 'random'],
    'classifier__base_estimator__max_depth': [30],
    'classifier__base_estimator__min_samples_split': [10, 5],
    'classifier__base_estimator__min_samples_leaf': [1],
    'classifier__base_estimator__class_weight': [None, 'balanced']}

grid_search_dt_cchain = GridSearchCV(
    estimator=pipeline_dt_cchain,
    param_grid=param_grid_dt_cchain,
    scoring=scores,
    refit="f1_weighted",
    verbose=4,
    cv = predefined_split)

grid_result_dt_cchain = grid_search_dt_cchain.fit(X_train_full, y_train_full)
# Out:
# Fitting 1 folds for each of 8 candidates, totalling 8 fits
# [CV 1/1] END classifier__base_estimator__class_weight=None, classifier__base_estimator__max_depth=30, classifier__base_estimator__min_samples_leaf=1, classifier__base_estimator__min_samples_split=10, classifier__order=None, vectorizer=TfidfVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.219) f1_weighted: (test=0.843) precision_weighted: (test=0.841) recall_weighted: (test=0.858) total time=  18.2s
# [CV 1/1] END classifier__base_estimator__class_weight=None, classifier__base_estimator__max_depth=30, classifier__base_estimator__min_samples_leaf=1, classifier__base_estimator__min_samples_split=10, classifier__order=random, vectorizer=TfidfVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.260) f1_weighted: (test=0.849) precision_weighted: (test=0.850) recall_weighted: (test=0.863) total time=  16.8s
# [CV 1/1] END classifier__base_estimator__class_weight=None, classifier__base_estimator__max_depth=30, classifier__base_estimator__min_samples_leaf=1, classifier__base_estimator__min_samples_split=5, classifier__order=None, vectorizer=TfidfVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.221) f1_weighted: (test=0.843) precision_weighted: (test=0.840) recall_weighted: (test=0.859) total time=  16.2s
# [CV 1/1] END classifier__base_estimator__class_weight=None, classifier__base_estimator__max_depth=30, classifier__base_estimator__min_samples_leaf=1, classifier__base_estimator__min_samples_split=5, classifier__order=random, vectorizer=TfidfVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.239) f1_weighted: (test=0.847) precision_weighted: (test=0.845) recall_weighted: (test=0.862) total time=  16.0s
# [CV 1/1] END classifier__base_estimator__class_weight=balanced, classifier__base_estimator__max_depth=30, classifier__base_estimator__min_samples_leaf=1, classifier__base_estimator__min_samples_split=10, classifier__order=None, vectorizer=TfidfVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.121) f1_weighted: (test=0.770) precision_weighted: (test=0.805) recall_weighted: (test=0.760) total time=  12.5s
# [CV 1/1] END classifier__base_estimator__class_weight=balanced, classifier__base_estimator__max_depth=30, classifier__base_estimator__min_samples_leaf=1, classifier__base_estimator__min_samples_split=10, classifier__order=random, vectorizer=TfidfVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.157) f1_weighted: (test=0.807) precision_weighted: (test=0.806) recall_weighted: (test=0.813) total time=  13.0s
# [CV 1/1] END classifier__base_estimator__class_weight=balanced, classifier__base_estimator__max_depth=30, classifier__base_estimator__min_samples_leaf=1, classifier__base_estimator__min_samples_split=5, classifier__order=None, vectorizer=TfidfVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.129) f1_weighted: (test=0.771) precision_weighted: (test=0.811) recall_weighted: (test=0.749) total time=  12.4s
# [CV 1/1] END classifier__base_estimator__class_weight=balanced, classifier__base_estimator__max_depth=30, classifier__base_estimator__min_samples_leaf=1, classifier__base_estimator__min_samples_split=5, classifier__order=random, vectorizer=TfidfVectorizer(token_pattern='(?u)\\b\\w+\\b'); accuracy: (test=0.171) f1_weighted: (test=0.810) precision_weighted: (test=0.809) recall_weighted: (test=0.814) total time=  17.1s

# %%
print("Best Parameters (Decision Trees Classifier Chain): ", grid_result_dt_cchain.best_params_)
# Out:
# Best Parameters (Decision Trees Classifier Chain):  {'classifier__base_estimator__class_weight': None, 'classifier__base_estimator__max_depth': 30, 'classifier__base_estimator__min_samples_leaf': 1, 'classifier__base_estimator__min_samples_split': 10, 'classifier__order': 'random', 'vectorizer': TfidfVectorizer(token_pattern='(?u)\\b\\w+\\b')}

# %%
for score in scores:
    mean_score = grid_result_dt_cchain.cv_results_[f'mean_test_{score}'][grid_result_dt_cchain.best_index_]
    print(f"Decision Tree Classifier Chain: \n{score} = {round(mean_score, 3)}")
# Out:
# Decision Tree Classifier Chain:
# accuracy = 0.26
# Decision Tree Classifier Chain:
# precision_weighted = 0.85
# Decision Tree Classifier Chain:
# recall_weighted = 0.863
# Decision Tree Classifier Chain:
# f1_weighted = 0.849
